# %%
import pandas as pd

# %%
df=pd.read_csv("../data/raw/tickets.csv")
print("✅ Dataset loaded successfully!")
# Out:
# ✅ Dataset loaded successfully!

# %%
print("\n --dataset shape --")
print(df.shape)
# Out:
#  --dataset shape --
# (27413, 2)

# %%
print("column names----");
print(df.columns.tolist());
# Out:
# column names----
# ['text', 'category']

# %%
print("missing values----")
print(df.isnull().sum())
# Out:
# missing values----
# text        0
# category    0
# dtype: int64

# %%
print('----Class Distribution---')
print(df['category'].value_counts())
# Out:
# ----Class Distribution---
# category
# general_inquiry    22778
# billing             2534
# technical_issue     1732
# password_reset       369
# Name: count, dtype: int64

# %%
import re
import nltk
from nltk.corpus import stopwords
# Out:
#   Cell In[17], line 3
#     import nltk.corpus import stopwords
#                        ^
# SyntaxError: invalid syntax

# %%
stop_words = set(stopwords.words('english'))

print(f"Total stopwords: {len(stop_words)}")
print(f'\n Examples : {sorted(list(stop_words))[:20]}')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 stop_words = set(stopwords.words('english'))
#       3 print(f"Total stopwords: {len(stop_words)}")
#       4 print(f'\n Examples : {sorted(list(stop_words))[:20]}')
#
# NameError: name 'stopwords' is not defined
